# %% [markdown]
# Importing and Cleaning Franklin's Data

# %%
# Packages
# For Cleaning and basic functions
import pandas as pd
import numpy as np
import requests
import json

# Connecting to Spotify API
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials

# %%
# Load the Excel file into a pandas DataFrame
franklin = "https://raw.githubusercontent.com/lphan1812/spotify-project/main/franklins.csv"

data = pd.read_csv(franklin)

#Delete the first row
data = data.drop(index=0)

print(data.columns)
# Out:
# Index(['Unnamed: 0', 'ts', 'username', 'platform', 'ms_played', 'conn_country',
#        'ip_addr_decrypted', 'user_agent_decrypted',
#        'master_metadata_track_name', 'master_metadata_album_artist_name',
#        'master_metadata_album_album_name', 'spotify_track_uri', 'episode_name',
#        'episode_show_name', 'spotify_episode_uri', 'reason_start',
#        'reason_end', 'shuffle', 'skipped', 'offline', 'offline_timestamp',
#        'incognito_mode'],
#       dtype='object')

# %%
# Load the Excel file into a pandas DataFrame
#data = pd.read_excel("franklin_data.xlsx", header=1)

# Split the spotify_track_uri column into three columns
data[['spotify', 'track', 'track_uri']] = data['spotify_track_uri'].str.split(':', n=2, expand=True)

# Remove the 'spotify:track:' string from the track_uri column
data['track_uri'] = data['track_uri'].str.replace('spotify:track:', '')

# Drop the 'spotify' and 'track' columns since we don't need them
data = data.drop(columns=['spotify', 'track'])

# Print the first few rows to verify the results
data.head()
# Out:
#    Unnamed: 0                    ts       username  \
# 1           1  2018-01-23T13:58:46Z  sir_frankster
# 2           2  2021-10-20T18:41:27Z  sir_frankster
# 3           3  2020-12-01T05:25:31Z  sir_frankster
# 4           4  2019-05-25T04:59:44Z  sir_frankster
# 5           5  2022-12-12T04:28:57Z  sir_frankster
#
#                              platform  ms_played conn_country  \
# 1              iOS 11.1.1 (iPhone8,1)     237300           US
# 2              iOS 12.0.1 (iPhone6,1)     242013           US
# 3  Windows 10 (10.0.18363; x64; AppX)      81544           US
# 4                OS X 10.14.4 [x86 8]       2316           US
# 5                                 osx     179491           US
#
#   ip_addr_decrypted user_agent_decrypted master_metadata_track_name  \
# 1      66.87.31.235              unknown                    7 Years
# 2     107.127.45.51              unknown            drivers license
# 3    108.53.217.176              unknown                  Piano Man
# 4      100.8.116.86              unknown       Push It to the Limit
# 5       24.2.197.91              unknown        Here You Come Again
#
#   master_metadata_album_artist_name  ... episode_show_name  \
# 1                      Lukas Graham  ...               NaN
# 2                    Olivia Rodrigo  ...               NaN
# 3                        Billy Joel  ...               NaN
# 4                       Corbin Bleu  ...               NaN
# 5                      Dolly Parton  ...               NaN
#
#   spotify_episode_uri reason_start reason_end shuffle skipped offline  \
# 1                 NaN    trackdone  trackdone    True     NaN   False
# 2                 NaN    trackdone  trackdone   False     NaN   False
# 3                 NaN    trackdone     logout   False     NaN   False
# 4                 NaN     clickrow    endplay    True     NaN   False
# 5                 NaN    trackdone  trackdone   False     0.0   False
#
#    offline_timestamp  incognito_mode               track_uri
# 1       1.516720e+12           False  5kqIPrATaCc2LqxVWzQGbk
# 2       1.634760e+12           False  5wANPM4fQCJwkGd4rN57mH
# 3       1.606600e+12           False  78WVLOP9pN0G3gRLFy1rAa
# 4       1.558760e+12           False  3K01q0jtSNHeqx5gs97HH2
# 5       1.670819e+09           False  6H7nDglS6xWpRidbhMwI2L
#
# [5 rows x 23 columns]

# %%
# save your IDs from new project in Spotify Developer Dashboard
CLIENT_ID = '08923f56c32e46c1ae4b4ff05260b76f'
CLIENT_SECRET = '226fd5b07d874db0a61e720c750d646c'

# generate access token

# authentication URL
AUTH_URL = 'https://accounts.spotify.com/api/token'

# POST
auth_response = requests.post(AUTH_URL, {
    'grant_type': 'client_credentials',
    'client_id': CLIENT_ID,
    'client_secret': CLIENT_SECRET,
})

# convert the response to JSON
auth_response_data = auth_response.json()

# save the access token
access_token = auth_response_data['access_token']

# used for authenticating all API calls
headers = {'Authorization': 'Bearer {token}'.format(token=access_token)}

# base URL of all Spotify API endpoints
BASE_URL = 'https://api.spotify.com/v1/'

# %%
data = data[data['track_uri'].notna()]
data['ts'] = pd.to_datetime(data['ts'])
last_six_months = data['ts'] >= (data['ts'].max() - pd.DateOffset(months=6))
last_six_months = data[last_six_months].sort_values('ms_played', ascending=False)
last_six_months
# Out:
#        Unnamed: 0                        ts       username platform  \
# 22030       22030 2023-04-18 01:56:21+00:00  sir_frankster      osx
# 18140       18140 2022-10-23 19:18:47+00:00  sir_frankster      ios
# 10038       10038 2023-03-17 22:45:19+00:00  sir_frankster      ios
# 906           906 2023-01-04 02:56:30+00:00  sir_frankster      osx
# 9589         9589 2023-02-23 01:13:09+00:00  sir_frankster      osx
# ...           ...                       ...            ...      ...
# 2382         2382 2022-11-22 22:27:06+00:00  sir_frankster      ios
# 4486         4486 2023-03-22 02:52:33+00:00  sir_frankster      osx
# 17021       17021 2023-03-07 01:38:06+00:00  sir_frankster      osx
# 13426       13426 2023-03-17 21:34:15+00:00  sir_frankster      ios
# 8968         8968 2023-02-27 00:57:03+00:00  sir_frankster      osx
#
#        ms_played conn_country ip_addr_decrypted user_agent_decrypted  \
# 22030     647283           US       24.2.197.91              unknown
# 18140     613026           US    166.196.106.67              unknown
# 10038     613026           US    107.115.20.162              unknown
# 906       613026           US       24.2.197.91              unknown
# 9589      525767           US       24.2.197.91              unknown
# ...          ...          ...               ...                  ...
# 2382           0           US   107.122.192.162              unknown
# 4486           0           US       24.2.197.91              unknown
# 17021          0           US       24.2.197.91              unknown
# 13426          0           US    107.115.20.162              unknown
# 8968           0           US       24.2.197.91              unknown
#
#                               master_metadata_track_name  \
# 22030                   The One That Got Away - Acoustic
# 18140  All Too Well (10 Minute Version) (Taylor's Ver...
# 10038  All Too Well (10 Minute Version) (Taylor's Ver...
# 906    All Too Well (10 Minute Version) (Taylor's Ver...
# 9589              A Million Dreams (Instrumental Guitar)
# ...                                                  ...
# 2382          I Want To Hold Your Hand - Remastered 2015
# 4486                             Lead Me Out of the Dark
# 17021                                       All About Us
# 13426               Candle In The Wind - Remastered 2014
# 8968                                 Cowboy Take Me Away
#
#       master_metadata_album_artist_name  ... episode_show_name  \
# 22030                        Katy Perry  ...               NaN
# 18140                      Taylor Swift  ...               NaN
# 10038                      Taylor Swift  ...               NaN
# 906                        Taylor Swift  ...               NaN
# 9589                     Guus Dielissen  ...               NaN
# ...                                 ...  ...               ...
# 2382                        The Beatles  ...               NaN
# 4486                   Crown The Empire  ...               NaN
# 17021                          He Is We  ...               NaN
# 13426                        Elton John  ...               NaN
# 8968                         The Chicks  ...               NaN
#
#       spotify_episode_uri reason_start reason_end shuffle skipped offline  \
# 22030                 NaN    trackdone    endplay   False     1.0   False
# 18140                 NaN       fwdbtn  trackdone    True     0.0   False
# 10038                 NaN    trackdone  trackdone    True     0.0   False
# 906                   NaN    trackdone  trackdone   False     0.0   False
# 9589                  NaN    trackdone  trackdone   False     0.0   False
# ...                   ...          ...        ...     ...     ...     ...
# 2382                  NaN    trackdone    endplay    True     1.0   False
# 4486                  NaN    trackdone    endplay   False     1.0   False
# 17021                 NaN    trackdone    endplay   False     1.0   False
# 13426                 NaN    trackdone    endplay    True     1.0   False
# 8968                  NaN    trackdone    backbtn   False     1.0   False
#
#        offline_timestamp  incognito_mode               track_uri
# 22030       1.681782e+09           False  4FFSK1xgCLkTZJLUERLZKG
# 18140       1.666552e+09           False  5enxwA8aAbwZbf5qCHORXi
# 10038       1.679093e+09           False  5enxwA8aAbwZbf5qCHORXi
# 906         1.672800e+09           False  5enxwA8aAbwZbf5qCHORXi
# 9589        1.677114e+09           False  0T482F5L30d7ChNbLqsKa7
# ...                  ...             ...                     ...
# 2382        1.669156e+09           False  4pbG9SUmWIvsROVLF0zF9s
# 4486        1.679454e+09           False  6h2YXTAX6QN83w0gOTjDZa
# 17021       1.678153e+09           False  0UQAkAVNk3tubJYlOHyG3q
# 13426       1.679089e+09           False  1L9fzw2pXprOqtemTwtxXF
# 8968        1.677459e+09           False  3rXCZRMiMZp0feGcYXpwYX
#
# [1909 rows x 23 columns]

# %%
last_six_months.to_csv('franklin_six_months.csv', index=False)

# %%
audio = last_six_months.drop_duplicates()

# %%
feature_dict = {}

# convert track_uri column to an iterable list
track_uris = audio['track_uri'].to_list()

# loop through track URIs and pull audio features using the API,
# store all these in a dictionary
for t_uri in track_uris:
    
    feature_dict[t_uri] = {'popularity': 0,
                           'danceability': 0,
                           'energy': 0,
                           'loudness':0,
                           'valence':0,
#                            'acousticness':0,
                           'speechiness': 0,
                           'instrumentalness': 0,
                           'tempo': 0}
#     audio_features_list =['artist', 'album', 'track_name', 'track_id', 'danceability', 'energy', 'key', 'loudness', 'mode', 
#                               'speechiness', 'instrumentalness', 'liveness', 'valence', 'tempo', 'duration_ms', 'time_signature', 'acousticness']
    r = requests.get(BASE_URL + 'tracks/' + t_uri, headers=headers)
    r = r.json()
    feature_dict[t_uri]['popularity'] = r['popularity']
    
    s = requests.get(BASE_URL + 'audio-features/' + t_uri, headers=headers)
    s = s.json()
    feature_dict[t_uri]['danceability'] = s['danceability']
    feature_dict[t_uri]['energy'] = s['energy']
    feature_dict[t_uri]['loudness'] = s['loudness']
    feature_dict[t_uri]['valence'] = s['valence']
#     feature_dict[t_uri]['acousticness'] = s['acousticness']
    feature_dict[t_uri]['speechiness'] = s['speechiness']
    feature_dict[t_uri]['instrumentalness'] = s['instrumentalness']
    feature_dict[t_uri]['tempo'] = s['tempo']

# %%
# convert dictionary into dataframe with track_uri as the first column
df_features = pd.DataFrame.from_dict(feature_dict, orient='index')
df_features.insert(0, 'track_uri', df_features.index)
df_features.reset_index(inplace=True, drop=True)

df_features
# Out:
#                   track_uri  popularity  danceability  energy  loudness  \
# 0    4FFSK1xgCLkTZJLUERLZKG          61         0.712   0.440   -11.566
# 1    5enxwA8aAbwZbf5qCHORXi          85         0.631   0.518    -8.771
# 2    0T482F5L30d7ChNbLqsKa7          43         0.414   0.235   -15.252
# 3    3EZTyh1wJEmreJH1aULPCj          62         0.323   0.106   -10.374
# 4    5Mw9bXG1dLNhbjofkVS2oR          69         0.262   0.361   -10.187
# ..                      ...         ...           ...     ...       ...
# 831  2cOUlop2ZakjOKe4WinesN          77         0.735   0.425    -6.648
# 832  0k6LV1ohcK2hlNPwu1nVw9          63         0.641   0.512    -4.935
# 833  6yhLR2sVn1IfsScVrR4ocr          60         0.416   0.341   -10.749
# 834  4pbG9SUmWIvsROVLF0zF9s          74         0.490   0.715    -5.549
# 835  6h2YXTAX6QN83w0gOTjDZa          44         0.473   0.468    -7.439
#
#      valence  speechiness  instrumentalness    tempo
# 0      0.312       0.0413          0.000000  123.958
# 1      0.205       0.0303          0.000000   93.023
# 2      0.137       0.0429          0.907000  144.467
# 3      0.158       0.0323          0.000059   91.455
# 4      0.056       0.0333          0.002680  126.786
# ..       ...          ...               ...      ...
# 831    0.848       0.0464          0.000000   85.896
# 832    0.395       0.0285          0.000000  116.059
# 833    0.776       0.0391          0.000000  177.229
# 834    0.866       0.0476          0.000000  130.726
# 835    0.448       0.0503          0.000000  119.680
#
# [836 rows x 9 columns]

# %%
df_features.to_csv('franklin_audio_features.csv', index=False)
